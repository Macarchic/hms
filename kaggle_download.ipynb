# %%
import kagglehub

# Download latest version
path = kagglehub.competition_download('hms-harmful-brain-activity-classification', output_dir=str(Path("./data").resolve()))

print("Path to competition files:", path)
# Out:
# ...
# 100%|██████████| 18.4G/18.4G [10:42<00:00, 30.8MB/s]
# Extracting files...
# Path to competition files: /Users/macarchic/Documents/unik/audio/hms/data
